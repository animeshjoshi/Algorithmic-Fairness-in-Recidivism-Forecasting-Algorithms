# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Probability Folds Merged.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     ID  Residence_PUMA  \
# 0           0            99    100              11
# 1           1          9984  10234              23
# 2           2         10561  10831               2
# 3           3         24292  25124               4
# 4           4         11328  11630               2
#
#    Supervision_Risk_Score_First  Prior_Arrest_Episodes_DVCharges  \
# 0                           6.0                                0
# 1                           6.0                                0
# 2                           6.0                                0
# 3                           1.0                                0
# 4                           8.0                                0
#
#    Prior_Arrest_Episodes_GunCharges  Prior_Conviction_Episodes_Viol  \
# 0                                 1                               0
# 1                                 0                               0
# ...

# %%
logistic_bin_one = df[(df['Logistic Regression Probabilities'] <= 0.1 ) & (df['Logistic Regression Probabilities'] >= 0 )]

# %%
logistic_bin_one
# Out:
#        Unnamed: 0  Unnamed: 0.1     ID  Residence_PUMA  \
# 103             0         24810  25672              24
# 138            35         15119  15548               4
# 164            61          4990   7347               7
# 1351           12         12118  12445              12
# 3181           91         25611  26525              21
# 3300            4          8526   8731               3
# 3759           51          5014   5141               9
# 4626           94          3092   3176               8
# 5526           67         10068  13001               4
# 5667            2          9610   9846               5
# 5669            4          3066   3150               5
# 5689           24         12474  12808               3
# 6205           25          3250   3340              17
# 7748           23         25663  26580              17
# 10862          47          8984  11175              17
# 11016          98          4049   4158               1
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Logistic Regression Probabilities'])
# Out:
# (array([  32.,  478., 1271., 1994., 3596., 5593., 6283., 4505., 1852.,
#          146.]),
#  array([7.22368655e-05, 1.00064986e-01, 2.00057735e-01, 3.00050483e-01,
#         4.00043232e-01, 5.00035981e-01, 6.00028730e-01, 7.00021479e-01,
#         8.00014228e-01, 9.00006976e-01, 9.99999725e-01]),
#  <BarContainer object of 10 artists>)

# %%
len(df)
# Out:
# 25750

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1     ID  Residence_PUMA  \
# 0               0            99    100              11
# 1               1          9984  10234              23
# 2               2         10561  10831               2
# 3               3         24292  25124               4
# 4               4         11328  11630               2
# ...           ...           ...    ...             ...
# 25745          98         25281  26177               8
# 25746          99          5455   5594              17
# 25747         100          6044   6193              17
# 25748         101         22520  23276              11
# 25749         102          2497   2553               8
#
#        Supervision_Risk_Score_First  Prior_Arrest_Episodes_DVCharges  \
# 0                               6.0                                0
# 1                               6.0                                0
# 2                               6.0                                0
# ...

# %%
len(logistic_bin_one[(logistic_bin_one['Race_WHITE'] == 1) & (logistic_bin_one['Actual Outcomes'] == 1)])/len(logistic_bin_one[(logistic_bin_one['Race_WHITE'] == 1)])
# Out:
# 0.1111111111111111

# %%
len(logistic_bin_one[(logistic_bin_one['Race_WHITE'] == 0) & (logistic_bin_one['Actual Outcomes'] == 1)])/len(logistic_bin_one[(logistic_bin_one['Race_WHITE'] == 0)])
# Out:
# 0.35714285714285715

# %%
len(logistic_bin_one[(logistic_bin_one['Race_WHITE'] == 0) & (logistic_bin_one['Actual Outcomes'] == 1)])
# Out:
# 5

# %%
len(logistic_bin_one[(logistic_bin_one['Race_WHITE'] == 0)])
# Out:
# 14
