# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NPR and PPR Distribution.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  LRPrivPPR  LRProtPPR  LRPrivNPR  LRProtNPR  LDAPrivPPR  \
# 0           0   0.152174   0.315789   0.847826   0.684211    0.260870
# 1           1   0.487805   0.290323   0.512195   0.709677    0.414634
# 2           2   0.448276   0.270270   0.551724   0.729730    0.517241
# 3           3   0.200000   0.095238   0.800000   0.904762    0.275000
# 4           4   0.240741   0.102041   0.759259   0.897959    0.351852
#
#    LDAProtPPR  LDAPrivNPR  LDAProtNPR  XGPrivPPR  XGProtPPR  XGPrivNPR  \
# 0    0.298246    0.739130    0.701754   0.326087   0.350877   0.673913
# 1    0.258065    0.585366    0.741935   0.463415   0.274194   0.536585
# 2    0.297297    0.482759    0.702703   0.482759   0.364865   0.517241
# 3    0.285714    0.725000    0.714286   0.275000   0.269841   0.725000
# 4    0.244898    0.648148    0.755102   0.370370   0.306122   0.629630
#
#    XGProtNPR  RFPrivPPR  RFProtPPR  RFPrivNPR  RFProtNPR
# 0   0.649123   0.239130   0.263158   0.760870   0.736842
# ...

# %%
nij_data = pd.read_csv('recidivism dataset.csv')

# %%
nij_data.head()
# Out:
#    Unnamed: 0  ID Gender   Race Age_at_Release  Residence_PUMA  \
# 0           0   1      M  BLACK          43-47              16
# 1           1   2      M  BLACK          33-37              16
# 2           2   3      M  BLACK    48 or older              24
# 3           3   4      M  WHITE          38-42              16
# 4           4   5      M  WHITE          33-37              16
#
#   Gang_Affiliated  Supervision_Risk_Score_First Supervision_Level_First  \
# 0           False                           3.0                Standard
# 1           False                           6.0             Specialized
# 2           False                           7.0                    High
# 3           False                           7.0                    High
# 4           False                           4.0             Specialized
#
#          Education_Level  ... DrugTests_Meth_Positive  \
# 0  At least some college  ...                0.000000
# ...

# %%
nij_data = nij_data.drop('Unnamed: 0', axis = 1)

# %%
nij_data.head()
# Out:
#    ID Gender   Race Age_at_Release  Residence_PUMA Gang_Affiliated  \
# 0   1      M  BLACK          43-47              16           False
# 1   2      M  BLACK          33-37              16           False
# 2   3      M  BLACK    48 or older              24           False
# 3   4      M  WHITE          38-42              16           False
# 4   5      M  WHITE          33-37              16           False
#
#    Supervision_Risk_Score_First Supervision_Level_First  \
# 0                           3.0                Standard
# 1                           6.0             Specialized
# 2                           7.0                    High
# 3                           7.0                    High
# 4                           4.0             Specialized
#
#          Education_Level Dependents  ... DrugTests_Meth_Positive  \
# 0  At least some college  3 or more  ...                0.000000
# 1   Less than HS diploma          1  ...                0.000000
# ...

# %%
nij_data['Race'].unique()
# Out:
# array(['BLACK', 'WHITE'], dtype=object)

# %%
nij_data.drop('Race', axis = 1).columns
# Out:
# Index(['ID', 'Gender', 'Age_at_Release', 'Residence_PUMA', 'Gang_Affiliated',
#        'Supervision_Risk_Score_First', 'Supervision_Level_First',
#        'Education_Level', 'Dependents', 'Prison_Offense', 'Prison_Years',
#        'Prior_Arrest_Episodes_Felony', 'Prior_Arrest_Episodes_Misd',
#        'Prior_Arrest_Episodes_Violent', 'Prior_Arrest_Episodes_Property',
#        'Prior_Arrest_Episodes_Drug',
#        'Prior_Arrest_Episodes_PPViolationCharges',
#        'Prior_Arrest_Episodes_DVCharges', 'Prior_Arrest_Episodes_GunCharges',
#        'Prior_Conviction_Episodes_Felony', 'Prior_Conviction_Episodes_Misd',
#        'Prior_Conviction_Episodes_Viol', 'Prior_Conviction_Episodes_Prop',
#        'Prior_Conviction_Episodes_Drug',
#        'Prior_Conviction_Episodes_PPViolationCharges',
#        'Prior_Conviction_Episodes_DomesticViolenceCharges',
#        'Prior_Conviction_Episodes_GunCharges', 'Prior_Revocations_Parole',
# ...

# %%
nij_data.head()
# Out:
#    ID Gender   Race Age_at_Release  Residence_PUMA Gang_Affiliated  \
# 0   1      M  BLACK          43-47              16           False
# 1   2      M  BLACK          33-37              16           False
# 2   3      M  BLACK    48 or older              24           False
# 3   4      M  WHITE          38-42              16           False
# 4   5      M  WHITE          33-37              16           False
#
#    Supervision_Risk_Score_First Supervision_Level_First  \
# 0                           3.0                Standard
# 1                           6.0             Specialized
# 2                           7.0                    High
# 3                           7.0                    High
# 4                           4.0             Specialized
#
#          Education_Level Dependents  ... DrugTests_Meth_Positive  \
# 0  At least some college  3 or more  ...                0.000000
# 1   Less than HS diploma          1  ...                0.000000
# ...

# %%
pd.get_dummies(nij_data, columns = ['Race', 'Age_at_Release', 'Gang_Affiliated', 'Supervision_Level_First', 'Education_Level', 'Deoendents'])

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('training_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25835 entries, 0 to 25834
# Columns: 140 entries, Unnamed: 0 to Residence_Changes_3 or more
# dtypes: float64(8), int64(132)
# memory usage: 27.6 MB

# %%
df = df.fillna(0)

# %%
df.drop('Unnamed: 0', axis = 1)
df.to_csv("training_data.csv")
